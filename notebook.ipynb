# %% [markdown]
# ### paragraph1
#
# 細胞は頑健性と可塑性の相反する２つを併せ持ってるよねみたいな

# %% [markdown]
# ### paragraph2
# 遺伝子型と表現型の関連性を見るには構造から動態へ視点を移す必要がある
#
# 表現型は時間的なprofileに依存するから？
# この辺よくわからん

# %% [markdown]
# ### paragraph3
# 著者はこの辺を批評ていうか離脱しようとしてる
#
#
# 最近の分子生物学の教義
# - 細胞は進化の産物である
# - 遺伝子型は表現型を決定する
#
# 還元主義的なアプローチ
# 単一, もしくは少数の遺伝子の起因する分子による現象を追求してる.
#
# "あらゆる分子相互作用を含む生物学的プロセスと細胞の機能性を、特定の機能に向かって強い選択によって最適化されたものとみなす大局的な見方"
